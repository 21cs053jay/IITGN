# %%
import pandas as pd
import numpy as np
import random

# %%
ArExponent_min, ArExponent_max = 1, 100
FExponent_min, FExponent_max = 1,100

Arflux1_min, Arflux1_max = 0.0001, 0.01
Arflux2_min, Arflux2_max = 0.0001, 0.01
Arflux3_min, Arflux3_max = 0.0001, 0.01
Arflux4_min, Arflux4_max = 0.0001, 0.01
Arflux5_min, Arflux5_max = 0.0001, 0.01
Arflux6_min, Arflux6_max = 0.0001, 0.01

Fflux1_min, Fflux1_max = 0.0001, 0.01
Fflux2_min, Fflux2_max = 0.0001, 0.01
Fflux3_min, Fflux3_max = 0.0001, 0.01
Fflux4_min, Fflux4_max = 0.0001, 0.01
Fflux5_min, Fflux5_max = 0.0001, 0.01
Fflux6_min, Fflux6_max = 0.0001, 0.01

yield_at_zero1_min, yield_at_zero1_max = 1,5
yield_at_zero2_min, yield_at_zero2_max = 1,5
yield_at_zero3_min, yield_at_zero3_max = 1,5

theta_max1_min, theta_max1_max = 30,90
theta_max2_min, theta_max1_max = 30,90
theta_max3_min, theta_max1_max = 30,90

mizk_min, mizk_max = 0.001,0.005

p1_min, p1_max = 0, 0.002
p2_min, p2_max = 0.8, 1
p3_min, p3_max = 0, 0.002
p4_min, p4_max = 0.5,0.9
p5_min, p5_max = 0, 0.0002

# %%
features = ['Arflux1','Arflux2','Arflux3','Arflux4','Arflux5','Arflux6','Arflux7','Arflux8',
            'Fflux1','Fflux2','Fflux3','Fflux4','Fflux5','Fflux6','Fflux7','Fflux8',
            'ArExponent','FrExponent',
            'yield_at_zero1','yield_at_zero2','yield_at_zero3',
            'yield_max1','yield_max2','yield_max3',
            'theta_max1','theta_max2','theta_max3','mizk',
            'p1','p2','p3','p4','p5']

# %%
feature_range_values = [[0.001,0.006],[0.001,0.006],[0.001,0.006],[0.001,0.006],[0.001,0.006],[0.001,0.006],[0.001,0.006],[0.001,0.006],
                        [0.001,0.006],[0.001,0.006],[0.001,0.006],[0.001,0.006],[0.001,0.006],[0.001,0.006],[0.001,0.006],[0.001,0.006],
                        [1,100],[1,100],
                        [1,5],[1,5],[1,5],
                        [1,10],[1,10],[1,10],
                        [30,90],[30,90],[30,90],[0.005,0.05],
                        [0, 0.002],[0.8, 1],[0, 0.002],[0.5,0.9],[0, 0.0002]]

# %%
features_ranges = {}
for i in range(len(features)):
    features_ranges[features[i]] = feature_range_values[i]

# %%
features_ranges
# Out:
# {'Arflux1': [0.001, 0.006],
#  'Arflux2': [0.001, 0.006],
#  'Arflux3': [0.001, 0.006],
#  'Arflux4': [0.001, 0.006],
#  'Arflux5': [0.001, 0.006],
#  'Arflux6': [0.001, 0.006],
#  'Arflux7': [0.001, 0.006],
#  'Arflux8': [0.001, 0.006],
#  'Fflux1': [0.001, 0.006],
#  'Fflux2': [0.001, 0.006],
#  'Fflux3': [0.001, 0.006],
#  'Fflux4': [0.001, 0.006],
#  'Fflux5': [0.001, 0.006],
#  'Fflux6': [0.001, 0.006],
#  'Fflux7': [0.001, 0.006],
#  'Fflux8': [0.001, 0.006],
#  'ArExponent': [1, 100],
#  'FrExponent': [1, 100],
#  'yield_at_zero1': [1, 5],
#  'yield_at_zero2': [1, 5],
#  'yield_at_zero3': [1, 5],
#  'yield_max1': [1, 10],
#  'yield_max2': [1, 10],
#  'yield_max3': [1, 10],
#  'theta_max1': [30, 90],
#  'theta_max2': [30, 90],
#  'theta_max3': [30, 90],
#  'mizk': [0.005, 0.05],
#  'p1': [0, 0.002],
#  'p2': [0.8, 1],
#  'p3': [0, 0.002],
#  'p4': [0.5, 0.9],
#  'p5': [0, 0.0002]}

# %%
num_samples = 200
number_of_features = len(features)

# %%
number_of_features
# Out:
# 33

# %%
X = np.empty((num_samples,number_of_features))
for i in range(num_samples):
    for j in range(number_of_features):
        X[i][j] = round(random.uniform(feature_range_values[j][0], feature_range_values[j][1]),4)

# %%
for i in range(len(X)):
    if (X[i][21] < X[i][18]):
        while (X[i][21] < X[i][18]):
            X[i][21] = round(random.uniform(feature_range_values[21][0], feature_range_values[21][1]),4)
    if (X[i][22] < X[i][19]):
        while (X[i][22] < X[i][19]):
            X[i][22] = round(random.uniform(feature_range_values[22][0], feature_range_values[22][1]),4)
    if (X[i][23] < X[i][20]):
        while (X[i][23] < X[i][20]):
            X[i][23] = round(random.uniform(feature_range_values[23][0], feature_range_values[23][1]),4)

# %%
X_dataframe = pd.DataFrame(X,columns = features)

# %%
X_dataframe
# Out:
#      Arflux1  Arflux2  Arflux3  Arflux4  Arflux5  Arflux6  Arflux7  Arflux8  \
# 0     0.0031   0.0042   0.0013   0.0055   0.0017   0.0021   0.0016   0.0055
# 1     0.0033   0.0042   0.0022   0.0048   0.0059   0.0054   0.0019   0.0033
# 2     0.0024   0.0054   0.0019   0.0016   0.0022   0.0040   0.0018   0.0035
# 3     0.0046   0.0049   0.0045   0.0043   0.0051   0.0051   0.0045   0.0034
# 4     0.0047   0.0047   0.0017   0.0028   0.0040   0.0019   0.0058   0.0010
# ..       ...      ...      ...      ...      ...      ...      ...      ...
# 195   0.0025   0.0059   0.0022   0.0017   0.0015   0.0030   0.0030   0.0034
# 196   0.0012   0.0014   0.0026   0.0032   0.0052   0.0052   0.0048   0.0044
# 197   0.0035   0.0037   0.0047   0.0015   0.0048   0.0015   0.0010   0.0026
# 198   0.0052   0.0030   0.0015   0.0046   0.0015   0.0022   0.0023   0.0019
# 199   0.0029   0.0015   0.0015   0.0010   0.0017   0.0013   0.0053   0.0052
#
#      Fflux1  Fflux2  ...  yield_max3  theta_max1  theta_max2  theta_max3  \
# 0    0.0033  0.0023  ...      7.2743     36.6475     59.0686     52.1991
# 1    0.0053  0.0050  ...      7.0453     40.7715     58.6282     58.5334
# 2    0.0045  0.0052  ...      8.2947     71.1733     39.6643     34.1910
# 3    0.0046  0.0044  ...      4.7336     59.6786     32.7108     30.1350
# 4    0.0042  0.0058  ...      8.3205     49.7824     88.2472     84.3097
# ..      ...     ...  ...         ...         ...         ...         ...
# 195  0.0048  0.0027  ...      7.6406     53.5674     87.8458     55.1487
# 196  0.0047  0.0060  ...      7.8559     70.5339     76.5409     39.5219
# 197  0.0028  0.0053  ...      7.7663     41.3703     35.0943     89.9337
# 198  0.0028  0.0042  ...      7.9614     50.3611     87.5432     79.5465
# 199  0.0039  0.0037  ...      6.4123     48.6987     73.5898     80.0175
#
#        mizk      p1      p2      p3      p4      p5
# 0    0.0302  0.0013  0.8701  0.0002  0.5603  0.0000
# 1    0.0400  0.0003  0.8526  0.0014  0.6477  0.0001
# 2    0.0238  0.0016  0.9502  0.0001  0.8570  0.0001
# 3    0.0348  0.0015  0.8808  0.0008  0.7728  0.0001
# 4    0.0065  0.0019  0.9872  0.0014  0.8490  0.0001
# ..      ...     ...     ...     ...     ...     ...
# 195  0.0125  0.0018  0.9706  0.0011  0.5900  0.0001
# 196  0.0136  0.0020  0.9976  0.0004  0.7428  0.0001
# 197  0.0230  0.0020  0.9932  0.0019  0.5709  0.0002
# 198  0.0498  0.0011  0.9471  0.0019  0.6616  0.0000
# 199  0.0360  0.0016  0.9077  0.0009  0.6728  0.0001
#
# [200 rows x 33 columns]

# %%
(X_dataframe['yield_max3'] < X_dataframe['yield_at_zero3']).sum()
# Out:
# 0

# %%
sed = "sed  -e 's/Arflux1/'$Arflux1'/g' -e 's/Arflux2/'$Arflux2'/g' -e 's/Arflux3/'$Arflux3'/g' -e 's/Arflux4/'$Arflux4'/g' -e 's/Arflux5/'$Arflux5'/g' -e 's/Arflux6/'$Arflux6'/g' -e 's/Arflux7/'$Arflux7'/g' -e 's/Arflux8/'$Arflux8'/g' -e 's/Fflux1/'$Fflux1'/g' -e 's/Fflux2/'$Fflux2'/g' -e 's/Fflux3/'$Fflux3'/g' -e 's/Fflux4/'$Fflux4'/g' -e 's/Fflux5/'$Fflux5'/g' -e 's/Fflux6/'$Fflux6'/g' -e 's/Fflux7/'$Fflux7'/g' -e 's/Fflux8/'$Fflux8'/g' -e 's/ArExponent/'$ArExponent'/g' -e 's/FrExponent/'$FrExponent'/g' -e 's/yield_at_zero1/'$yield_at_zero1'/g' -e 's/yield_max1/'$yield_max1'/g' -e 's/theta_max1/'$theta_max1'/g' -e 's/yield_at_zero2/'$yield_at_zero2'/g' -e 's/yield_max2/'$yield_max2'/g' -e 's/theta_max2/'$theta_max2'/g' -e 's/yield_at_zero3/'$yield_at_zero3'/g' -e 's/yield_max3/'$yield_max3'/g' -e 's/theta_max3/'$theta_max3'/g' -e 's/mizk/'$mizk'/g' -e 's/p1/'$p1'/g' -e 's/p2/'$p2'/g' -e 's/p3/'$p3'/g' -e 's/p4/'$p4'/g' -e 's/p5/'$p5'/g' -e 's/etch_time/'$etch_time'/g' etching.cmd > temp_etching.cmd\n"
sed2 = "sed  -e 's/Arflux1/'$Arflux1'/g' -e 's/Arflux2/'$Arflux2'/g' -e 's/Arflux3/'$Arflux3'/g' -e 's/Arflux4/'$Arflux4'/g' -e 's/Arflux5/'$Arflux5'/g' -e 's/Arflux6/'$Arflux6'/g' -e 's/Arflux7/'$Arflux7'/g' -e 's/Arflux8/'$Arflux8'/g' -e 's/Fflux1/'$Fflux1'/g' -e 's/Fflux2/'$Fflux2'/g' -e 's/Fflux3/'$Fflux3'/g' -e 's/Fflux4/'$Fflux4'/g' -e 's/Fflux5/'$Fflux5'/g' -e 's/Fflux6/'$Fflux6'/g' -e 's/Fflux7/'$Fflux7'/g' -e 's/Fflux8/'$Fflux8'/g' -e 's/ArExponent/'$ArExponent'/g' -e 's/FrExponent/'$FrExponent'/g' -e 's/yield_at_zero1/'$yield_at_zero1'/g' -e 's/yield_max1/'$yield_max1'/g' -e 's/theta_max1/'$theta_max1'/g' -e 's/yield_at_zero2/'$yield_at_zero2'/g' -e 's/yield_max2/'$yield_max2'/g' -e 's/theta_max2/'$theta_max2'/g' -e 's/yield_at_zero3/'$yield_at_zero3'/g' -e 's/yield_max3/'$yield_max3'/g' -e 's/theta_max3/'$theta_max3'/g' -e 's/mizk/'$mizk'/g' -e 's/p1/'$p1'/g' -e 's/p2/'$p2'/g' -e 's/p3/'$p3'/g' -e 's/p4/'$p4'/g' -e 's/p5/'$p5'/g' -e 's/etch_time/'$etch_time'/g' etching_data_extraction.cmd > temp_etching_data_extraction.cmd\n"

# %%
file_name = ''
for feature in features:
    file_name+=f"_{feature}"

# %%
file_name
# Out:
# '_Arflux1_Arflux2_Arflux3_Arflux4_Arflux5_Arflux6_Arflux7_Arflux8_Fflux1_Fflux2_Fflux3_Fflux4_Fflux5_Fflux6_Fflux7_Fflux8_ArExponent_FrExponent_yield_at_zero1_yield_at_zero2_yield_at_zero3_yield_max1_yield_max2_yield_max3_theta_max1_theta_max2_theta_max3_mizk_p1_p2_p3_p4_p5'

# %%
run_files = 'stopo temp_etching.cmd\nstopo temp_etching_data_extraction.cmd\n'

# %%
text  = ''

for i in range(len(X)):
    
    params = ''
    dir_name = ''
    for j in range(len(X[0])):
        params += f'{features[j]}={X[i][j]}\n'
        dir_name += f'_{X[i][j]}'
    text+= f'mkdir -p csvfiles/file{dir_name}\n'
    for k in range(8):
        text+= 'export '
        text += params
        text += f"etch_time={2*(k+1)}\n"
        text += sed
        text += sed2
        text += run_files

# %%
with open('/Users/nimitt/Documents/SRIP/SemiconductorFabrication/DatasetGeneration/TestDataset/shell_test_16.sh','w') as file:
    file.write(text)

# %%
X_dataframe.to_csv('/Users/nimitt/Documents/SRIP/SemiconductorFabrication/DatasetGeneration/dataset_X.txt')
